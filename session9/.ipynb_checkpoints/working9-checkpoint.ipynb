# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# !ls -ltr
# !hostname -i
# Out:
# total 167272
# drwxr-xr-x 2 abhinav abhinav      4096 Jun  5  2009 cifar-10-batches-py
# -rw-r--r-- 1 abhinav abhinav        24 Sep 25 21:56 readme.md
# drwxr-xr-x 3 abhinav abhinav      4096 Sep 25 21:56 model_file
# -rw-r--r-- 1 abhinav abhinav    269211 Sep 25 21:56 EVA5_session_9.ipynb
# drwxr-xr-x 3 abhinav abhinav      4096 Sep 25 21:56 data_augmentation
# -rw-r--r-- 1 abhinav abhinav 170498071 Sep 25 22:49 cifar-10-python.tar.gz
# drwxr-xr-x 4 abhinav abhinav      4096 Sep 25 22:54 mlruns
# -rw-r--r-- 1 abhinav abhinav     11803 Sep 25 23:28 model_architecture
# -rw-r--r-- 1 abhinav abhinav     42973 Sep 26 00:15 model_history.png
# -rw-r--r-- 1 abhinav abhinav    146238 Sep 26 00:15 Test_missclassified_images.jpg
# -rw-r--r-- 1 abhinav abhinav    285833 Sep 26 01:04 working9.ipynb
# drwxr-xr-x 4 abhinav abhinav      4096 Sep 26 01:10 model_utility
# 127.0.1.1

# %% [markdown]
# # Loading UD modules

# %% [raw]
# !ls -R

# %% [raw]
# !pip install albumentations -y

# %%
from __future__ import print_function
import torch
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
from torchsummary import summary
from tqdm import tqdm
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import os 
import numpy as np
#mlflow
import mlflow
import mlflow.pytorch

# CUSTOM LIBRARY
import model_utility.data_utils as dutils
import model_utility.model_utils as mutils
import model_utility.plot_utils as putils 
import model_utility.regularization as regularization
import model_file.model_cifar as model_cifar
import model_utility.alb_utils as alb
import sys
sys.path.append('/home/abhinav/Documents/EVA5/session9/model_utility/gradcam')
import model_utility.grad_cam_viz as viz
import model_file.models as mod

# PLOTS
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-810c9899a14d> in <module>
#      24 import sys
#      25 sys.path.append('../model_utility/gradcam')
# ---> 26 import model_utility.grad_cam_viz as viz
#      27 import model_file.models as mod
#      28
#
# ~/Documents/EVA5/session9/model_utility/grad_cam_viz.py in <module>
#       8 import matplotlib.pyplot as plt
#       9
# ---> 10 from gradcam import visualize_cam
#      11 from gradcam import GradCAM, GradCAMpp
#      12
#
# ModuleNotFoundError: No module named 'gradcam'

# %%
import data_augmentation.albumentations as A
from data_augmentation.albumentations.pytorch import ToTensor

# %%
A.__version__
A.__file__
A.Compose.__module__
A.Cutout.__module__
A.RandomCrop.__module__
A.HorizontalFlip.__module__
A.ElasticTransform.__module__
A.CoarseDropout.__module__
A.Normalize.__module__
A.pytorch.ToTensor.__module__
A.pytorch.ToTensor.__module__
# Out:
# '0.4.6'
# '/home/abhinav/Documents/EVA5/session9/data_augmentation/albumentations/__init__.py'
# 'data_augmentation.albumentations.core.composition'
# 'data_augmentation.albumentations.augmentations.transforms'
# 'data_augmentation.albumentations.augmentations.transforms'
# 'data_augmentation.albumentations.augmentations.transforms'
# 'data_augmentation.albumentations.augmentations.transforms'
# 'data_augmentation.albumentations.augmentations.transforms'
# 'data_augmentation.albumentations.augmentations.transforms'
# 'data_augmentation.albumentations.pytorch.transforms'
# 'data_augmentation.albumentations.pytorch.transforms'

# %% [markdown]
# # Check GPU avaiability

# %%
device = dutils.get_device()
# Out:
# CUDA Available? True
# Device is cuda:0

# %%
cuda = torch.cuda.is_available()
print(cuda)
# Out:
# True

# %% [markdown]
# # CIFAR10 Basics

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

SEED = 1
batch_size=128

# CUDA?
if device.type == 'cuda':
    torch.cuda.manual_seed(SEED)
else:
    torch.manual_seed(SEED)

# %% [markdown]
# # Load CIFAR10 dataset

# %%
os.getcwd()
# Out:
# '/home/abhinav/Documents/EVA5/session9'

# %%
path = os.getcwd()
path
# Out:
# '/home/abhinav/Documents/EVA5/session9'

# %% [raw]
# # load CIFAR10 dataset
# train_loader, test_loader = dutils.get_dataloader(batch_size=batch_size, num_workers=4, cuda = True,path = path )

# %%
batch_size = 128

# %%
# load CIFAR10 dataset
trainset, testset, train_loader, test_loader = alb.get_dataloader(batch_size=batch_size, num_workers=4, cuda = True,path = path)
# Out:
# Running over Cuda !!  True
# Files already downloaded and verified
# Files already downloaded and verified
# mean 0.49186864
# standard dev 0.24697131
# mean 0.48265335
# standard dev 0.24338901
# mean 0.44717798
# standard dev 0.26159254
# /home/abhinav/anaconda3/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:1469: DeprecationWarning: This class has been deprecated. Please use CoarseDropout
#   warnings.warn("This class has been deprecated. Please use CoarseDropout", DeprecationWarning)
# /home/abhinav/anaconda3/lib/python3.8/site-packages/albumentations/pytorch/transforms.py:57: DeprecationWarning: ToTensor is deprecated and will be replaced by ToTensorV2 in albumentations 0.5.0
#   warnings.warn(
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Data mage Visualization

# %%
#Plot 20 random images
putils.plot_dataset_images(device, classes, train_loader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Model stracture

# %%
model = mod.ResNet18()

# %%
mutils.model_summary(model, device, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %% [markdown]
# # Visual Summary

# %%
# from model_utility.plot_utils import  graphical_summary_cifar10
# graphical_summary_cifar10(model)

# %%
# Create CIFAR10 network
# model = model_cifar.Net(dropout_value = 0.05)
# mutils.model_summary(model, device, input_size=(3, 32, 32))

# %% [markdown]
# # Build and train model

# %%
from tqdm import tqdm

# %%
# build and train the model
model_name = "Model CIFAR10"
EPOCHS = 20
model =  model.to(device) # use GPU

# using L1 and L2 regularization
train_acc, train_losses, test_acc, test_losses = mutils.build_model(model, 
                                                            device, 
                                                            trainloader=train_loader, 
                                                            testloader=test_loader, 
                                                            epochs=EPOCHS,
                                                            L1_loss_flag=False,
                                                            L2_penalty_val=0.001)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 0
# Loss=2.011525 Batch_id=390 Accuracy=29.59: 100%|██████████| 391/391 [00:46<00:00,  8.37it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.658039, Accuracy: 3919/10000 (39.19%)
#
# EPOCH: 1
# Loss=1.455039 Batch_id=390 Accuracy=46.58: 100%|██████████| 391/391 [00:47<00:00,  8.30it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.352119, Accuracy: 5125/10000 (51.25%)
#
# EPOCH: 2
# Loss=1.227334 Batch_id=390 Accuracy=55.69: 100%|██████████| 391/391 [00:47<00:00,  8.22it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.080468, Accuracy: 6208/10000 (62.08%)
#
# EPOCH: 3
# Loss=1.021637 Batch_id=390 Accuracy=63.72: 100%|██████████| 391/391 [00:47<00:00,  8.15it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.195339, Accuracy: 5998/10000 (59.98%)
#
# EPOCH: 4
# Loss=0.896191 Batch_id=390 Accuracy=68.62: 100%|██████████| 391/391 [00:48<00:00,  8.11it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.348737, Accuracy: 5960/10000 (59.60%)
#
# EPOCH: 5
# Loss=0.829568 Batch_id=390 Accuracy=71.04: 100%|██████████| 391/391 [00:48<00:00,  8.10it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.884818, Accuracy: 6982/10000 (69.82%)
#
# EPOCH: 6
# Loss=0.790207 Batch_id=390 Accuracy=72.40: 100%|██████████| 391/391 [00:48<00:00,  8.08it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.751178, Accuracy: 7446/10000 (74.46%)
#
# EPOCH: 7
# Loss=0.745445 Batch_id=390 Accuracy=73.89: 100%|██████████| 391/391 [00:49<00:00,  7.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.089993, Accuracy: 6579/10000 (65.79%)
#
# EPOCH: 8
# Loss=0.495501 Batch_id=390 Accuracy=83.02: 100%|██████████| 391/391 [00:48<00:00,  8.09it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.459054, Accuracy: 8416/10000 (84.16%)
#
# EPOCH: 9
# Loss=0.404913 Batch_id=390 Accuracy=85.94: 100%|██████████| 391/391 [00:48<00:00,  8.10it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.428078, Accuracy: 8530/10000 (85.30%)
#
# EPOCH: 10
# Loss=0.360433 Batch_id=390 Accuracy=87.59: 100%|██████████| 391/391 [00:49<00:00,  7.95it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.420991, Accuracy: 8552/10000 (85.52%)
#
# EPOCH: 11
# Loss=0.319643 Batch_id=390 Accuracy=89.06: 100%|██████████| 391/391 [00:48<00:00,  8.06it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.434414, Accuracy: 8541/10000 (85.41%)
#
# EPOCH: 12
# Loss=0.289876 Batch_id=390 Accuracy=89.92: 100%|██████████| 391/391 [00:48<00:00,  8.09it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.425481, Accuracy: 8585/10000 (85.85%)
#
# EPOCH: 13
# Loss=0.260677 Batch_id=390 Accuracy=90.99: 100%|██████████| 391/391 [00:48<00:00,  8.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.448529, Accuracy: 8526/10000 (85.26%)
#
# EPOCH: 14
# Loss=0.239011 Batch_id=390 Accuracy=91.83: 100%|██████████| 391/391 [00:48<00:00,  8.09it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.451454, Accuracy: 8524/10000 (85.24%)
#
# EPOCH: 15
# Loss=0.220452 Batch_id=390 Accuracy=92.41: 100%|██████████| 391/391 [00:48<00:00,  8.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.539900, Accuracy: 8359/10000 (83.59%)
#
# EPOCH: 16
# Loss=0.142044 Batch_id=390 Accuracy=95.52: 100%|██████████| 391/391 [00:48<00:00,  8.12it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.390845, Accuracy: 8740/10000 (87.40%)
#
# EPOCH: 17
# Loss=0.113173 Batch_id=390 Accuracy=96.58: 100%|██████████| 391/391 [00:48<00:00,  8.01it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.386942, Accuracy: 8763/10000 (87.63%)
#
# EPOCH: 18
# Loss=0.098818 Batch_id=390 Accuracy=97.01: 100%|██████████| 391/391 [00:49<00:00,  7.97it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.384291, Accuracy: 8763/10000 (87.63%)
#
# EPOCH: 19
# Loss=0.091951 Batch_id=390 Accuracy=97.28: 100%|██████████| 391/391 [00:48<00:00,  8.08it/s]
# Test set: Average loss: 0.392583, Accuracy: 8756/10000 (87.56%)

# %%
A.__file__
# Out:
# '/home/abhinav/Documents/EVA5/session9/data_augmentation/albumentations/__init__.py'

# %% [markdown]
# # Test Accuracy

# %%
mutils.get_test_accuracy(model, device, test_loader)
# Out:
# Accuracy of the network on the 10000 test images: 87.56%

# %% [markdown]
# ### Class level Accuracy

# %%
mutils.class_based_accuracy(model, device, classes, test_loader)
# Out:
# Accuracy of plane : 96 %
# Accuracy of   car : 93 %
# Accuracy of  bird : 80 %
# Accuracy of   cat : 60 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 80 %
# Accuracy of  frog : 82 %
# Accuracy of horse : 95 %
# Accuracy of  ship : 97 %
# Accuracy of truck : 87 %

# %% [markdown]
# # Visualization

# %%
print("\nPloting Accuracy and Loss history: {}\n".format(model_name))
putils.plot_model_history(model_name, 
                   train_acc,test_acc,
                   train_losses,test_losses,
                   save_filename = "model_history")
# Out:
# Ploting Accuracy and Loss history: Model CIFAR10
# /home/abhinav/Documents/EVA5/session9/model_utility/plot_utils.py:27: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1,x_size+1),x_size/10)
# /home/abhinav/Documents/EVA5/session9/model_utility/plot_utils.py:38: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1,x_size+1),x_size/10)

# %% [markdown]
# # Misclassified images

# %%
print ("\nPloting misclassified images: {}\n".format(model_name))

putils.miss_classification('Test',model, 
                          device, 
                          classes,
                          testloader=test_loader,
                          num_of_images = 20,
                          save_filename="model_misclassified")
# Out:
# Ploting misclassified images: Model CIFAR10
# /home/abhinav/Documents/EVA5/session9/model_utility/plot_utils.py:86: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629395347/work/torch/csrc/utils/python_arg_parser.cpp:766.)
#   wrong_idx = (pred_marker == False).nonzero()  # get indices for wrong predictions
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
layer = 'layer4'
GCAM(layer,model,testset,classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-9cff2ea4502d> in <module>
#       1 layer = 'layer4'
# ----> 2 GCAM(layer,model,testset,classes)
#
# NameError: name 'GCAM' is not defined

# %%
with mlflow.start_run() as run:
    mlflow.log_param("epochs", EPOCHS)
    mlflow.pytorch.log_model(model, "models")
